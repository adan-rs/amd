# %% [markdown]
# # Práctica 3: Pruebas de asociación
#
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/adan-rs/amd/blob/main/practicas/Practica_3.ipynb)
#
# **Objetivo General**: Los estudiantes desarrollarán habilidades para realizar pruebas estadísticas de asociación entre variables cualitativas y cuantitativas mediante el uso de bases de datos reales y la interpretación detallada de los resultados obtenidos.
#
#
# *Caso 1: Relación entre sentimiento y aerolíneas*
#
# Instrucciones:
#
# - Carga de la base de datos: Importa la base de datos aerolineas.xlsx a tu entorno de trabajo.
# - Revisión de datos: Realiza un análisis exploratorio inicial para verificar la estructura de los datos: Muestra las primeras filas del dataset. Verifica la existencia de datos faltantes y, si es necesario, realiza una limpieza básica.
#
# Tablas de contingencia:
#
# - Genera una tabla de contingencia que relacione las categorías de sentimientos (positivo, neutral y negativo) con las aerolíneas.
#
# Prueba Chi Cuadrado:
#
# - Realiza una prueba de Chi Cuadrado para determinar si existe una asociación significativa entre las variables.
# - Presenta los valores de la estadística Chi Cuadrado, los grados de libertad y el p-valor.
#
# Interpretación:
#
# - Describe en un párrafo tus hallazgos en base al p-valor obtenido y concluye si existe o no una asociación significativa entre los sentimientos expresados en los mensajes y las aerolíneas mencionadas.
#
#
#
# *Caso 2: Relación entre ingreso y variables de gasto*
#
# Instrucciones:
#
# - Carga de la base de datos: Importa la base de datos enigh2025.xlsx a tu entorno de trabajo.
# - Revisión de datos: Realiza un análisis exploratorio inicial:
# - Inspecciona las primeras filas del dataset.
# - Identifica las variables relevantes: 'ingreso corriente' y las variables de gasto `['alimentos','cereales','carnes','leche','huevo','bebidas','agua','energia','cuida_pers']`.
# - Verifica la existencia de valores atípicos y ajusta los datos si es necesario.
#
# Prueba de correlación:
#
# - Calcula el coeficiente de correlación de Pearson entre el ingreso y cada una de las variables de gasto seleccionadas.
# - Realiza una prueba de hipótesis para cada correlación obtenida (H0: No hay correlación significativa, H1: Hay correlación significativa).
# - Presenta el valor del coeficiente de correlación, el p-valor asociado y concluye para cada prueba.
#
# Visualización:
#
# - Crea un gráfico de dispersión para el par de variables que presenten una mayor correlación significativa.
#
# Interpretación: Describe en un párrafo tus hallazgos.
#
# - ¿Qué variables presentan una relación significativa con el ingreso?
#
# - ¿La dirección y magnitud de las correlaciones tienen sentido en el contexto del problema? Justifica tus respuestas.
#
#
# ## Uso de IA Generativa (para profundizar)
#
# Se espera que utilices una herramienta de IA Generativa (por ejemplo, ChatGPT, Copilot, Claude, Gemini u otra similar) no para resolver directamente la práctica, sino para **ir más allá de lo que se pide**.
#
# Puedes usarla para:
# - Explorar interpretaciones adicionales de los resultados.
# - Proponer visualizaciones alternativas o métricas complementarias.
# - Reflexionar sobre posibles extensiones del análisis.
#
# Comparte el *prompt* utilizado y la respuesta o resultado obtenido.
#
# **Formato de Entrega**:
#
# Exporta tu código a formato pdf o html y súbelo a la plataforma del curso. Además, incluye un documento con tu análisis e interpretación de resultados (en formato pdf o docx):
#
# Código:
#
# - Bien documentado y estructurado con celdas Markdown para describir cada paso. Incluir tablas y resultados relevantes
#
# Reporte:
#
# - Incluye comentarios detallados sobre el significado de los resultados obtenidos.
#
# ## Rúbrica de evaluación
# 1. **Preparación y revisión de los datos (20%)**: carga correcta, exploración inicial y limpieza básica en ambos casos.
# 2. **Aplicación correcta de las pruebas (30%)**: tabla de contingencia y prueba chi cuadrada; correlaciones con sus pruebas de hipótesis, correctamente ejecutadas y reportadas.
# 3. **Interpretación y conclusiones (30%)**: conclusiones correctas a partir de los p-valores y discusión con sentido de negocio.
# 4. **Extensión del análisis con IA Generativa (20%)**: uso de la IA para ir más allá de lo solicitado, mediante un prompt que muestre una reflexión crítica de los objetivos.
#
# **Defensa oral**: cualquier práctica puede ser seleccionada al azar para una defensa oral breve (3 a 5 minutos), en la que deberás explicar tus decisiones, tu código y tus conclusiones. Un trabajo que no pueda ser explicado por su autor se considerará evidencia de trabajo no auténtico y podrá ser penalizado.
