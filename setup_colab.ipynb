# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/adan-rs/amd/blob/main/setup_colab.ipynb)
#
# # Bienvenido al curso de Análisis de Datos en Python
#
# Este notebook te ayudará a preparar tu entorno de trabajo en Google Colab.
#
# ## ¿Qué vamos a hacer?
#
# 1. Montar tu Google Drive para poder guardar una copia de los archivos del curso.
# 2. Clonar el repositorio oficial del curso desde GitHub.
# 3. Cambiar al directorio del repositorio.
# 4. Instalar todas las dependencias necesarias (pandas, numpy, matplotlib, scikit-learn, etc.).
# 5. Verificar que todo se instaló correctamente.
# 6. (Opcional) Copiar todo el repositorio a tu Google Drive para conservarlo.
#
# > **Recomendación**: Ejecuta una celda a la vez, esperando a que termine antes de pasar a la siguiente.
# > **Nota**: Después de instalar las dependencias, Colab puede pedirte reiniciar el runtime. Si aparece un mensaje, hazlo y luego continúa con las siguientes celdas.

# %%
# Paso 1: Montar Google Drive 
from google.colab import drive
drive.mount('/content/drive')

# %%
# Paso 2: Clonar repositorio
# !git clone https://github.com/adan-rs/amd.git

# %%
# Paso 3: Cambiar al directorio del repositorio
# %cd amd

# %%
# Paso 4: Instalar dependencias necesarias
# %pip install -r requirements.txt

# %% [markdown]
# ## (Opcional) Copiar repositorio a Google Drive
#
# Si deseas conservar una copia del repositorio en tu Google Drive, ejecuta la siguiente celda:

# %%
# (Opcional) Copiar repositorio completo a Google Drive
# !cp -r /content/amd /content/drive/MyDrive/analisis-datos
print("✅ Repositorio copiado a Google Drive en: /content/drive/MyDrive/analisis-datos")

# %%
# Paso 5: Verificar instalación
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("✅ Todas las dependencias se instalaron correctamente")
print(f"📦 Pandas versión: {pd.__version__}")
print(f"📦 NumPy versión: {np.__version__}")
